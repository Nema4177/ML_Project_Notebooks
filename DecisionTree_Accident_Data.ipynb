# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_df = pd.read_csv('All_numbers.csv')
train_df.head()
# Out:
#    Unnamed: 0   ID  Severity  Start_Lat  Start_Lng    End_Lat    End_Lng  \
# 0           0  A-1         3  40.108910 -83.092860  40.112060 -83.031870
# 1           1  A-2         2  39.865420 -84.062800  39.865010 -84.048730
# 2           2  A-3         2  39.102660 -84.524680  39.102090 -84.523960
# 3           3  A-4         2  41.062130 -81.537840  41.062170 -81.535470
# 4           4  A-5         3  39.172393 -84.492792  39.170476 -84.501798
#
#    Distance(mi)  Side  City  ...  Roundabout  Station   Stop Traffic_Calming  \
# 0         3.230     2   481  ...       False    False  False           False
# 1         0.747     2   108  ...       False    False  False           False
# 2         0.055     2   160  ...       False    False  False           False
# 3         0.123     2   561  ...       False    False  False           False
# 4         0.500     2   160  ...       False    False  False           False
#
#    Traffic_Signal  Turning_Loop  Sunrise_Sunset  Civil_Twilight  \
# 0           False         False               3               3
# 1           False         False               3               3
# 2           False         False               3               3
# 3           False         False               3               3
# 4           False         False               2               2
#
#    Nautical_Twilight  Astronomical_Twilight
# 0                  3                      3
# 1                  3                      3
# 2                  3                      2
# 3                  2                      2
# 4                  2                      2
#
# [5 rows x 41 columns]

# %%
train_df.drop('Unnamed: 0', axis=1, inplace=True)
train_df.drop('ID', axis=1, inplace=True)
train_df.drop('Country', axis=1, inplace=True)

# %%
train_df.drop('Wind_Chill(F)', axis=1, inplace=True)
train_df.drop('Humidity(%)', axis=1, inplace=True)
train_df.drop('Wind_Speed(mph)', axis=1, inplace=True)
train_df.drop('Precipitation(in)', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-69cfb1ca6c47> in <module>()
# ----> 1 train_df.drop('Wind_Chill(F)', axis=1, inplace=True)
#       2 train_df.drop('Humidity(%)', axis=1, inplace=True)
#       3 train_df.drop('Wind_Speed(mph)', axis=1, inplace=True)
#       4 train_df.drop('Precipitation(in)', axis=1, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Wind_Chill(F)'] not found in axis"

# %%
train_df.head()
# Out:
#    Severity  Start_Lat  Start_Lng    End_Lat    End_Lng  Distance(mi)  Side  \
# 0         3  40.108910 -83.092860  40.112060 -83.031870         3.230     2
# 1         2  39.865420 -84.062800  39.865010 -84.048730         0.747     2
# 2         2  39.102660 -84.524680  39.102090 -84.523960         0.055     2
# 3         2  41.062130 -81.537840  41.062170 -81.535470         0.123     2
# 4         3  39.172393 -84.492792  39.170476 -84.501798         0.500     2
#
#    City  County  State  ...  Roundabout  Station   Stop  Traffic_Calming  \
# 0   481     119     25  ...       False    False  False            False
# 1   108      15     25  ...       False    False  False            False
# 2   160      43     25  ...       False    False  False            False
# 3   561     171     25  ...       False    False  False            False
# 4   160      43     25  ...       False    False  False            False
#
#    Traffic_Signal  Turning_Loop  Sunrise_Sunset  Civil_Twilight  \
# 0           False         False               3               3
# 1           False         False               3               3
# 2           False         False               3               3
# 3           False         False               3               3
# 4           False         False               2               2
#
#    Nautical_Twilight  Astronomical_Twilight
# 0                  3                      3
# 1                  3                      3
# 2                  3                      2
# 3                  2                      2
# 4                  2                      2
#
# [5 rows x 34 columns]

# %%
y = train_df["Severity"]
y = y-1
np.unique(y)
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
train_df.drop('Severity', axis=1, inplace=True)
train_df.head()
# Out:
#    Start_Lat  Start_Lng    End_Lat    End_Lng  Distance(mi)  Side  City  \
# 0  40.108910 -83.092860  40.112060 -83.031870         3.230     2   481
# 1  39.865420 -84.062800  39.865010 -84.048730         0.747     2   108
# 2  39.102660 -84.524680  39.102090 -84.523960         0.055     2   160
# 3  41.062130 -81.537840  41.062170 -81.535470         0.123     2   561
# 4  39.172393 -84.492792  39.170476 -84.501798         0.500     2   160
#
#    County  State  Zipcode  ...  Roundabout  Station   Stop  Traffic_Calming  \
# 0     119     25    43017  ...       False    False  False            False
# 1      15     25    45424  ...       False    False  False            False
# 2      43     25    45203  ...       False    False  False            False
# 3     171     25    44311  ...       False    False  False            False
# 4      43     25    45217  ...       False    False  False            False
#
#    Traffic_Signal  Turning_Loop  Sunrise_Sunset  Civil_Twilight  \
# 0           False         False               3               3
# 1           False         False               3               3
# 2           False         False               3               3
# 3           False         False               3               3
# 4           False         False               2               2
#
#    Nautical_Twilight  Astronomical_Twilight
# 0                  3                      3
# 1                  3                      3
# 2                  3                      2
# 3                  2                      2
# 4                  2                      2
#
# [5 rows x 33 columns]

# %%
train_df.columns.values.tolist()
# Out:
# ['Start_Lat',
#  'Start_Lng',
#  'End_Lat',
#  'End_Lng',
#  'Distance(mi)',
#  'Side',
#  'City',
#  'County',
#  'State',
#  'Zipcode',
#  'Timezone',
#  'Temperature(F)',
#  'Pressure(in)',
#  'Visibility(mi)',
#  'Wind_Direction',
#  'Weather_Condition',
#  'Amenity',
#  'Bump',
#  'Crossing',
#  'Give_Way',
#  'Junction',
#  'No_Exit',
#  'Railway',
#  'Roundabout',
#  'Station',
#  'Stop',
#  'Traffic_Calming',
#  'Traffic_Signal',
#  'Turning_Loop',
#  'Sunrise_Sunset',
#  'Civil_Twilight',
#  'Nautical_Twilight',
#  'Astronomical_Twilight']

# %%
import copy

frames = copy.deepcopy(train_df)

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import MinMaxScaler

# for column in train_df:
#   print(column)
#   scaler = MinMaxScaler()
#   data = np.array(train_df[column])
#   data = data.reshape(data.shape[0], 1)
#   scaler.fit(data)
#   #print(scaler.data_max_)
#   data = scaler.transform(data)
#   print(np.max(data))
#   train_df[column] = data

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.ensemble import AdaBoostClassifier

X_train, X_test, y_train, y_test = train_test_split(train_df, y, test_size=0.2, random_state=1)

# %%
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1 score:",metrics.f1_score(y_test, y_pred, average='weighted'))
# Out:
# Accuracy: 0.8768391882179489
# F1 score: 0.878106332933228

# %%
depths = list(range(5,55,5))
depths
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
max_depth = 5
accuracies = []
f1_scores = []
while max_depth<=50:
  clf = DecisionTreeClassifier(max_depth=max_depth)

  # Train Decision Tree Classifer
  clf = clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)
  accuracy = metrics.accuracy_score(y_test, y_pred)
  accuracies.append(accuracy)
  f1_score = metrics.f1_score(y_test, y_pred, average='weighted')
  f1_scores.append(f1_score)
  print("Depth is "+str(max_depth)+" Accuracy is "+str(accuracy)+" F1 score is"+str(f1_score))
  max_depth += 5
print("Accuracies are "+str(accuracies))
print("F1 scores are "+str(f1_scores))
# Out:
# Depth is 5 Accuracy is 0.8956137129240918 F1 score is0.8555039290154492
# Depth is 10 Accuracy is 0.9019890382361365 F1 score is0.8767870455975124
# Depth is 15 Accuracy is 0.9040116400647373 F1 score is0.8846035638798294
# Depth is 20 Accuracy is 0.9015391806617475 F1 score is0.8873548621570938
# Depth is 25 Accuracy is 0.8956576443278408 F1 score is0.8870802890162881
# Depth is 30 Accuracy is 0.8881488887990736 F1 score is0.8839254660097129
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-9922478f61d8> in <module>()
#       6
#       7   # Train Decision Tree Classifer
# ----> 8   clf = clf.fit(X_train,y_train)
#       9
#      10   #Predict the response for test dataset
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     940             sample_weight=sample_weight,
#     941             check_input=check_input,
# --> 942             X_idx_sorted=X_idx_sorted,
#     943         )
#     944         return self
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
plt.plot(depths, f1_scores)
plt.title("f1_scores")
plt.show()

# %%
plt.plot(depths,accuracies)
plt.title("Accuracies ")
plt.show()

# %%
#Ensemble methods
abc = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
# Train Adaboost Classifer
model = abc.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1 score:",metrics.f1_score(y_test, y_pred, average='weighted'))
